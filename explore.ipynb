# %%
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport
from pandas_profiling import profile_report


# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/lpaes/projects/RealState/data/input/real-state-ny/data.csv')
df.columns.values
# Out:
# array(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS',
#        'BATHS', 'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT',
#        'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH', 'STATUS',
#        'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE',
#        'LONGITUDE'], dtype=object)

# %%
df.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0  MLS Listing        NaN                  Townhouse
# 1  MLS Listing        NaN                  Townhouse
# 2  MLS Listing        NaN  Single Family Residential
# 3  MLS Listing        NaN  Single Family Residential
# 4  MLS Listing        NaN                Condo/Co-op
#
#                     ADDRESS              CITY STATE OR PROVINCE  \
# 0              90-27 186 St            Queens                NY
# 1              26 Lester Ct          Brooklyn                NY
# 2             9444 226th St       Floral Park                NY
# 3           117-51 126th St  South Ozone Park                NY
# 4  99-31 64th Ave Unit A-15            Queens                NY
#
#    ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  ...  STATUS  \
# 0               11423  799000   3.0    2.0  ...  Active
# 1               11229  595000   2.0    2.5  ...  Active
# 2               11001  719000   3.0    2.0  ...  Active
# 3               11420  599000   3.0    2.0  ...  Active
# 4               11374  349000   1.0    1.0  ...  Active
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  https://www.redfin.com/NY/Queens/90-27-186th-S...
# 1  https://www.redfin.com/NY/Brooklyn/26-Lester-C...
# 2  https://www.redfin.com/NY/Floral-Park/9444-226...
# 3  https://www.redfin.com/NY/Queens/117-51-126th-...
# 4  https://www.redfin.com/NY/Rego-Park/9931-64th-...
#
#    SOURCE          MLS#  FAVORITE INTERESTED   LATITUDE  LONGITUDE
# 0   REBNY  PRCH-5000297         N          Y  40.711273 -73.773791
# 1   REBNY  PRCH-4376702         N          Y  40.587760 -73.924742
# 2  OneKey       3446280         N          Y  40.721218 -73.729240
# 3  OneKey       3441422         N          Y  40.673777 -73.811913
# 4   REBNY  PRCH-3974324         N          Y  40.731750 -73.853580
#
# [5 rows x 27 columns]

# %%
df.isna().sum()

# %%
#df.profile_report()

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\lpaes\AppData\Local\Temp\ipykernel_27696\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.head().style.background_gradient(cmap = "inferno")
# Out:
# c:\Users\lpaes\projects\RealState\.venv\lib\site-packages\pandas\io\formats\style.py:3925: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# c:\Users\lpaes\projects\RealState\.venv\lib\site-packages\pandas\io\formats\style.py:3926: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_12ded_row0_col1, #T_12ded_row1_col1, #T_12ded_row2_col1, #T_12ded_row3_col1, #T_12ded_row4_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_12ded_row0_col6, #T_12ded_row0_col7, #T_12ded_row0_col8, #T_12ded_row1_col9, #T_12ded_row2_col8, #T_12ded_row2_col26, #T_12ded_row3_col8, #T_12ded_row4_col12, #T_12ded_row4_col13, #T_12ded_row4_col14, #T_12ded_row4_col25 {
#   background-color: #fcffa4;
#   color: #000000;
# }
# #T_12ded_row0_col9, #T_12ded_row2_col9, #T_12ded_row3_col9 {
#   background-color: #ed6925;
#   color: #f1f1f1;
# }
# #T_12ded_row0_col11, #T_12ded_row0_col14, #T_12ded_row0_col15, #T_12ded_row0_col16, #T_12ded_row1_col11, #T_12ded_row1_col12, #T_12ded_row1_col15, #T_12ded_row1_col16, #T_12ded_row1_col25, #T_12ded_row1_col26, #T_12ded_row2_col6, #T_12ded_row2_col11, #T_12ded_row2_col15, #T_12ded_row2_col16, #T_12ded_row3_col11, #T_12ded_row3_col13, #T_12ded_row3_col15, #T_12ded_row3_col16, #T_12ded_row4_col7, #T_12ded_row4_col8, #T_12ded_row4_col9, #T_12ded_row4_col11, #T_12ded_row4_col15, #T_12ded_row4_col16 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_12ded_row0_col12, #T_12ded_row2_col12 {
#   background-color: #02010a;
#   color: #f1f1f1;
# }
# #T_12ded_row0_col13, #T_12ded_row2_col13 {
#   background-color: #3b0964;
#   color: #f1f1f1;
# }
# #T_12ded_row0_col25 {
#   background-color: #fac228;
#   color: #000000;
# }
# #T_12ded_row0_col26 {
#   background-color: #fb9706;
#   color: #000000;
# }
# #T_12ded_row1_col6 {
#   background-color: #ca404a;
#   color: #f1f1f1;
# }
# #T_12ded_row1_col7 {
#   background-color: #cb4149;
#   color: #f1f1f1;
# }
# #T_12ded_row1_col8 {
#   background-color: #bc3754;
#   color: #f1f1f1;
# }
# #T_12ded_row1_col13 {
#   background-color: #87216b;
#   color: #f1f1f1;
# }
# #T_12ded_row1_col14 {
#   background-color: #510e6c;
#   color: #f1f1f1;
# }
# #T_12ded_row2_col7 {
#   background-color: #fcb014;
#   color: #000000;
# }
# #T_12ded_row2_col14 {
#   background-color: #ab2f5e;
#   color: #f1f1f1;
# }
# #T_12ded_row2_col25 {
#   background-color: #f3e55d;
#   color: #000000;
# }
# #T_12ded_row3_col6 {
#   background-color: #fafda1;
#   color: #000000;
# }
# #T_12ded_row3_col7 {
#   background-color: #cf4446;
#   color: #f1f1f1;
# }
# #T_12ded_row3_col12 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_12ded_row3_col14 {
#   background-color: #f1ed71;
#   color: #000000;
# }
# #T_12ded_row3_col25 {
#   background-color: #db503b;
#   color: #f1f1f1;
# }
# #T_12ded_row3_col26 {
#   background-color: #d54a41;
#   color: #f1f1f1;
# }
# #T_12ded_row4_col6 {
#   background-color: #f8cf3a;
#   color: #000000;
# }
# #T_12ded_row4_col26 {
#   background-color: #85216b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_12ded">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12ded_level0_col0" class="col_heading level0 col0" >SALE TYPE</th>
#       <th id="T_12ded_level0_col1" class="col_heading level0 col1" >SOLD DATE</th>
#       <th id="T_12ded_level0_col2" class="col_heading level0 col2" >PROPERTY TYPE</th>
#       <th id="T_12ded_level0_col3" class="col_heading level0 col3" >ADDRESS</th>
#       <th id="T_12ded_level0_col4" class="col_heading level0 col4" >CITY</th>
#       <th id="T_12ded_level0_col5" class="col_heading level0 col5" >STATE OR PROVINCE</th>
#       <th id="T_12ded_level0_col6" class="col_heading level0 col6" >ZIP OR POSTAL CODE</th>
#       <th id="T_12ded_level0_col7" class="col_heading level0 col7" >PRICE</th>
#       <th id="T_12ded_level0_col8" class="col_heading level0 col8" >BEDS</th>
#       <th id="T_12ded_level0_col9" class="col_heading level0 col9" >BATHS</th>
#       <th id="T_12ded_level0_col10" class="col_heading level0 col10" >LOCATION</th>
#       <th id="T_12ded_level0_col11" class="col_heading level0 col11" >SQUARE FEET</th>
#       <th id="T_12ded_level0_col12" class="col_heading level0 col12" >LOT SIZE</th>
#       <th id="T_12ded_level0_col13" class="col_heading level0 col13" >YEAR BUILT</th>
#       <th id="T_12ded_level0_col14" class="col_heading level0 col14" >DAYS ON MARKET</th>
#       <th id="T_12ded_level0_col15" class="col_heading level0 col15" >$/SQUARE FEET</th>
#       <th id="T_12ded_level0_col16" class="col_heading level0 col16" >HOA/MONTH</th>
#       <th id="T_12ded_level0_col17" class="col_heading level0 col17" >STATUS</th>
#       <th id="T_12ded_level0_col18" class="col_heading level0 col18" >NEXT OPEN HOUSE START TIME</th>
#       <th id="T_12ded_level0_col19" class="col_heading level0 col19" >NEXT OPEN HOUSE END TIME</th>
#       <th id="T_12ded_level0_col20" class="col_heading level0 col20" >URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)</th>
#       <th id="T_12ded_level0_col21" class="col_heading level0 col21" >SOURCE</th>
#       <th id="T_12ded_level0_col22" class="col_heading level0 col22" >MLS#</th>
#       <th id="T_12ded_level0_col23" class="col_heading level0 col23" >FAVORITE</th>
#       <th id="T_12ded_level0_col24" class="col_heading level0 col24" >INTERESTED</th>
#       <th id="T_12ded_level0_col25" class="col_heading level0 col25" >LATITUDE</th>
#       <th id="T_12ded_level0_col26" class="col_heading level0 col26" >LONGITUDE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12ded_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12ded_row0_col0" class="data row0 col0" >MLS Listing</td>
#       <td id="T_12ded_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_12ded_row0_col2" class="data row0 col2" >Townhouse</td>
#       <td id="T_12ded_row0_col3" class="data row0 col3" >90-27 186 St</td>
#       <td id="T_12ded_row0_col4" class="data row0 col4" >Queens</td>
#       <td id="T_12ded_row0_col5" class="data row0 col5" >NY</td>
#       <td id="T_12ded_row0_col6" class="data row0 col6" >11423</td>
#       <td id="T_12ded_row0_col7" class="data row0 col7" >799000</td>
#       <td id="T_12ded_row0_col8" class="data row0 col8" >3.000000</td>
#       <td id="T_12ded_row0_col9" class="data row0 col9" >2.000000</td>
#       <td id="T_12ded_row0_col10" class="data row0 col10" >Hollis</td>
#       <td id="T_12ded_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_12ded_row0_col12" class="data row0 col12" >2500.000000</td>
#       <td id="T_12ded_row0_col13" class="data row0 col13" >1925.000000</td>
#       <td id="T_12ded_row0_col14" class="data row0 col14" >6</td>
#       <td id="T_12ded_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_12ded_row0_col16" class="data row0 col16" >nan</td>
#       <td id="T_12ded_row0_col17" class="data row0 col17" >Active</td>
#       <td id="T_12ded_row0_col18" class="data row0 col18" >nan</td>
#       <td id="T_12ded_row0_col19" class="data row0 col19" >nan</td>
#       <td id="T_12ded_row0_col20" class="data row0 col20" >https://www.redfin.com/NY/Queens/90-27-186th-St-11423/home/20765210</td>
#       <td id="T_12ded_row0_col21" class="data row0 col21" >REBNY</td>
#       <td id="T_12ded_row0_col22" class="data row0 col22" >PRCH-5000297</td>
#       <td id="T_12ded_row0_col23" class="data row0 col23" >N</td>
#       <td id="T_12ded_row0_col24" class="data row0 col24" >Y</td>
#       <td id="T_12ded_row0_col25" class="data row0 col25" >40.711273</td>
#       <td id="T_12ded_row0_col26" class="data row0 col26" >-73.773791</td>
#     </tr>
#     <tr>
#       <th id="T_12ded_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12ded_row1_col0" class="data row1 col0" >MLS Listing</td>
#       <td id="T_12ded_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_12ded_row1_col2" class="data row1 col2" >Townhouse</td>
#       <td id="T_12ded_row1_col3" class="data row1 col3" >26 Lester Ct</td>
#       <td id="T_12ded_row1_col4" class="data row1 col4" >Brooklyn</td>
#       <td id="T_12ded_row1_col5" class="data row1 col5" >NY</td>
#       <td id="T_12ded_row1_col6" class="data row1 col6" >11229</td>
#       <td id="T_12ded_row1_col7" class="data row1 col7" >595000</td>
#       <td id="T_12ded_row1_col8" class="data row1 col8" >2.000000</td>
#       <td id="T_12ded_row1_col9" class="data row1 col9" >2.500000</td>
#       <td id="T_12ded_row1_col10" class="data row1 col10" >Gerristen Beach</td>

# %%
df.describe().T.style.background_gradient(cmap = "viridis")
# Out:
# <style type="text/css">
# #T_2acc0_row0_col0, #T_2acc0_row1_col2, #T_2acc0_row1_col7, #T_2acc0_row3_col1, #T_2acc0_row3_col2, #T_2acc0_row3_col3, #T_2acc0_row3_col4, #T_2acc0_row3_col5, #T_2acc0_row3_col6, #T_2acc0_row3_col7, #T_2acc0_row4_col1, #T_2acc0_row4_col2, #T_2acc0_row4_col3, #T_2acc0_row4_col4, #T_2acc0_row4_col5, #T_2acc0_row4_col6, #T_2acc0_row4_col7, #T_2acc0_row5_col1, #T_2acc0_row5_col2, #T_2acc0_row5_col4, #T_2acc0_row5_col5, #T_2acc0_row5_col6, #T_2acc0_row5_col7, #T_2acc0_row7_col1, #T_2acc0_row7_col2, #T_2acc0_row7_col5, #T_2acc0_row7_col6, #T_2acc0_row7_col7, #T_2acc0_row8_col1, #T_2acc0_row8_col2, #T_2acc0_row8_col3, #T_2acc0_row8_col4, #T_2acc0_row8_col5, #T_2acc0_row8_col6, #T_2acc0_row8_col7, #T_2acc0_row9_col1, #T_2acc0_row9_col2, #T_2acc0_row9_col3, #T_2acc0_row9_col4, #T_2acc0_row9_col5, #T_2acc0_row9_col6, #T_2acc0_row9_col7, #T_2acc0_row10_col1, #T_2acc0_row10_col2, #T_2acc0_row10_col3, #T_2acc0_row10_col4, #T_2acc0_row10_col5, #T_2acc0_row10_col6, #T_2acc0_row10_col7, #T_2acc0_row11_col1, #T_2acc0_row11_col2, #T_2acc0_row11_col3, #T_2acc0_row11_col4, #T_2acc0_row11_col5, #T_2acc0_row11_col6, #T_2acc0_row11_col7, #T_2acc0_row12_col1, #T_2acc0_row12_col2, #T_2acc0_row12_col3, #T_2acc0_row12_col4, #T_2acc0_row12_col5, #T_2acc0_row12_col6, #T_2acc0_row12_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_2acc0_row0_col1, #T_2acc0_row0_col2, #T_2acc0_row0_col3, #T_2acc0_row0_col4, #T_2acc0_row0_col5, #T_2acc0_row0_col6, #T_2acc0_row0_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2acc0_row1_col0, #T_2acc0_row2_col0, #T_2acc0_row2_col1, #T_2acc0_row2_col2, #T_2acc0_row2_col3, #T_2acc0_row2_col4, #T_2acc0_row2_col5, #T_2acc0_row2_col6, #T_2acc0_row2_col7, #T_2acc0_row3_col0, #T_2acc0_row8_col0, #T_2acc0_row11_col0, #T_2acc0_row12_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_2acc0_row1_col1, #T_2acc0_row1_col6, #T_2acc0_row5_col3, #T_2acc0_row6_col4, #T_2acc0_row6_col5, #T_2acc0_row7_col4 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_2acc0_row1_col3 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_2acc0_row1_col4 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_2acc0_row1_col5, #T_2acc0_row6_col2, #T_2acc0_row6_col7 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_2acc0_row4_col0 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_2acc0_row5_col0, #T_2acc0_row9_col0 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_2acc0_row6_col0 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_2acc0_row6_col1, #T_2acc0_row6_col3, #T_2acc0_row6_col6 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_2acc0_row7_col0 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_2acc0_row7_col3 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_2acc0_row10_col0 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2acc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2acc0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_2acc0_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_2acc0_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2acc0_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2acc0_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_2acc0_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_2acc0_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_2acc0_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2acc0_level0_row0" class="row_heading level0 row0" >SOLD DATE</th>
#       <td id="T_2acc0_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_2acc0_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_2acc0_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_2acc0_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_2acc0_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_2acc0_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_2acc0_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_2acc0_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2acc0_level0_row1" class="row_heading level0 row1" >ZIP OR POSTAL CODE</th>
#       <td id="T_2acc0_row1_col0" class="data row1 col0" >350.000000</td>
#       <td id="T_2acc0_row1_col1" class="data row1 col1" >10664.614286</td>
#       <td id="T_2acc0_row1_col2" class="data row1 col2" >586.493306</td>
#       <td id="T_2acc0_row1_col3" class="data row1 col3" >10001.000000</td>
#       <td id="T_2acc0_row1_col4" class="data row1 col4" >10030.000000</td>
#       <td id="T_2acc0_row1_col5" class="data row1 col5" >10463.000000</td>
#       <td id="T_2acc0_row1_col6" class="data row1 col6" >11230.000000</td>
#       <td id="T_2acc0_row1_col7" class="data row1 col7" >11692.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2acc0_level0_row2" class="row_heading level0 row2" >PRICE</th>
#       <td id="T_2acc0_row2_col0" class="data row2 col0" >350.000000</td>
#       <td id="T_2acc0_row2_col1" class="data row2 col1" >1535017.562857</td>
#       <td id="T_2acc0_row2_col2" class="data row2 col2" >2321343.505279</td>
#       <td id="T_2acc0_row2_col3" class="data row2 col3" >105000.000000</td>
#       <td id="T_2acc0_row2_col4" class="data row2 col4" >499250.000000</td>
#       <td id="T_2acc0_row2_col5" class="data row2 col5" >837000.000000</td>
#       <td id="T_2acc0_row2_col6" class="data row2 col6" >1565000.000000</td>
#       <td id="T_2acc0_row2_col7" class="data row2 col7" >24950000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2acc0_level0_row3" class="row_heading level0 row3" >BEDS</th>
#       <td id="T_2acc0_row3_col0" class="data row3 col0" >349.000000</td>
#       <td id="T_2acc0_row3_col1" class="data row3 col1" >2.607450</td>
#       <td id="T_2acc0_row3_col2" class="data row3 col2" >1.998002</td>
#       <td id="T_2acc0_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_2acc0_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_2acc0_row3_col5" class="data row3 col5" >2.000000</td>
#       <td id="T_2acc0_row3_col6" class="data row3 col6" >3.000000</td>
#       <td id="T_2acc0_row3_col7" class="data row3 col7" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2acc0_level0_row4" class="row_heading level0 row4" >BATHS</th>
#       <td id="T_2acc0_row4_col0" class="data row4 col0" >346.000000</td>
#       <td id="T_2acc0_row4_col1" class="data row4 col1" >2.092486</td>
#       <td id="T_2acc0_row4_col2" class="data row4 col2" >1.509430</td>
#       <td id="T_2acc0_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_2acc0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2acc0_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_2acc0_row4_col6" class="data row4 col6" >2.500000</td>
#       <td id="T_2acc0_row4_col7" class="data row4 col7" >16.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2acc0_level0_row5" class="row_heading level0 row5" >SQUARE FEET</th>
#       <td id="T_2acc0_row5_col0" class="data row5 col0" >233.000000</td>
#       <td id="T_2acc0_row5_col1" class="data row5 col1" >1733.429185</td>
#       <td id="T_2acc0_row5_col2" class="data row5 col2" >1465.073587</td>
#       <td id="T_2acc0_row5_col3" class="data row5 col3" >348.000000</td>
#       <td id="T_2acc0_row5_col4" class="data row5 col4" >862.000000</td>
#       <td id="T_2acc0_row5_col5" class="data row5 col5" >1200.000000</td>
#       <td id="T_2acc0_row5_col6" class="data row5 col6" >2133.000000</td>
#       <td id="T_2acc0_row5_col7" class="data row5 col7" >12000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2acc0_level0_row6" class="row_heading level0 row6" >LOT SIZE</th>
#       <td id="T_2acc0_row6_col0" class="data row6 col0" >294.000000</td>
#       <td id="T_2acc0_row6_col1" class="data row6 col1" >13711.394558</td>
#       <td id="T_2acc0_row6_col2" class="data row6 col2" >28043.060345</td>
#       <td id="T_2acc0_row6_col3" c

# %%
col = ['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'CITY',
       'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS',
       'BATHS', 'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT',
       'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH', 'STATUS',
       'NEXT OPEN HOUSE START TIME', 'SOURCE', 
       'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE']
df_col = df.columns

# %%
df_col
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
list(set(df_col)-set(col))
# Out:
# ['URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#  'ADDRESS',
#  'NEXT OPEN HOUSE END TIME']
